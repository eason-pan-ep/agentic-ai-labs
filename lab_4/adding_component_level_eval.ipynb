# %% [markdown]
# # Adding a component-level eval to the research workflow

# %%
# Setup

# -- Standard Library
from datetime import datetime
import json
import re
from dotenv import load_dotenv
import os

# -- Third Party
from google import genai
from google.genai import types

# -- Local / Project
import research_tools
import utils

load_dotenv()
CLIENT = genai.Client(api_key=os.getenv("GOOGLE_API_KEY"))

# %% [markdown]
# ### Research Steps

# %%
def find_references(task: str, model: str = "gemini-2.5-flash", return_messages: bool = False):
    """Perform a research task using external tools (arxiv, tavily, wikipedia)."""

    prompt = f"""
    You are a research expert with access to:
    - arxiv_tool: academic papers
    - tavily_tool: general web search (return JSON when asked)
    - wikipedia_tool: encyclopedic summaries

    Task:
    {task}

    Today is {datetime.now().strftime('%Y-%m-%d')}.
    """.strip()

    tools = [
        research_tools.arxiv_search_tool,
        research_tools.tavily_search_tool,
        research_tools.wikipedia_search_tool,
    ]

    try:
        config = types.GenerateContentConfig(
            tools=tools,
            system_instruction="You are a research expert. For each results, mark the sources. Consider using web search tool if needed. Do not return conversation before you are done with tools and have a good result.",
        )
        response = CLIENT.models.generate_content(
            model=model,
            contents=prompt,
            config=config,
        )
        content = response.text

        # -- OpenAI setup
        # response = client.chat.completions.create(
        #     model=model,
        #     messages=messages,
        #     tools=tools,
        #     tool_choice="auto",
        #     max_turns=5,
        # )
        # content = response.choices[0].message.content

        return (content, prompt) if return_messages else content
    except Exception as e:
        return f"[Model Error: {e}]"

# %%
research_task = "Find 2 recent papers about recent developments in black hole science"
research_result = find_references(research_task)

# %%
print(research_result)
utils.print_html(
    research_result,
    title="Research Function Output"
)
# Out:
# Here are two recent papers about developments in black hole science:
#
# 1.  **Title:** Black Holes with Skyrme Hair
#     *   **Authors:** Noriko Shiiki, Nobuyuki Sawado
#     *   **Published:** 2005-01-09
#     *   **Summary:** This paper reviews recent developments on black holes with Skyrme hair, including the discovery of spherically symmetric black hole skyrmions with B=1 and axially symmetric B=2 black hole skyrmions. It discusses how black holes can absorb baryon number, leading to fractional charge outside the horizon. The paper also extends the model to gauged versions for monopole black hole skyrmions and explores multi-black hole skyrmion solutions where gravitational, electromagnetic, and strong forces are balanced, proving their stability under perturbations.
#     *   **Source:** arXiv (http://arxiv.org/abs/gr-qc/0501025v1)
#
# 2.  **Title:** Galaxy bulges and their massive black holes: a review
#     *   **Authors:** Alister W. Graham
#     *   **Published:** 2015-01-13
#     *   **Summary:** This article reviews the historical development of our understanding of massive black holes at galactic centers, including the evolution of the (black hole)-(host spheroid) mass relation and its recent revisions. It also addresses past disagreements about the slope of the (black hole)-(velocity dispersion) relation and discusses the discovery of substructure within this diagram. The paper presents various competing black hole mass scaling relations for samples of predominantly inactive galaxies as the search for the fundamental connection between massive black holes and their host galaxies continues.
#     *   **Source:** arXiv (http://arxiv.org/abs/1501.02937v3)
#     <style>
#     .pretty-card{
#       font-family: ui-sans-serif, system-ui;
#       border: 2px solid transparent;
#       border-radius: 14px;
#       padding: 14px 16px;
#       margin: 10px 0;
#       background: linear-gradient(#fff, #fff) padding-box,
#                   linear-gradient(135deg, #3b82f6, #9333ea) border-box;
#       color: #111;
#       box-shadow: 0 4px 12px rgba(0,0,0,.08);
#     }
#     .pretty-title{
#       font-weight:700;
#       margin-bottom:8px;
#       font-size:14px;
#       color:#111;
#     }
#     /* 🔒 Solo afecta lo DENTRO de la tarjeta */
#     .pretty-card pre,
#     .pretty-card code {
#       background: #f3f4f6;
#       color: #111;
#       padding: 8px;
#       border-radius: 8px;
#       display: block;
#       overflow-x: auto;
#       font-size: 13px;
#       white-space: pre-wrap;
#     }
#     .pretty-card img { max-width: 100%; height: auto; border-radius: 8px; }
#     .pretty-card table.pretty-table {
#       border-collapse: collapse;
#       width: 100%;
#       font-size: 13px;
#       color: #111;
#     }
#     .pretty-card table.pretty-table th,
#     .pretty-card table.pretty-table td {
#       border: 1px solid #e5e7eb;
#       padding: 6px 8px;
#       text-align: left;
#     }
#     .pretty-card table.pretty-table th { background: #f9fafb; font-weight: 600; }
#     </style>
#     <div class="pretty-card"><div class="pretty-title">Research Function Output</div><pre><code>Here are two recent papers about developments in black hole science:
#
# 1.  **Title:** Black Holes with Skyrme Hair
#     *   **Authors:** Noriko Shiiki, Nobuyuki Sawado
#     *   **Published:** 2005-01-09
#     *   **Summary:** This paper reviews recent developments on black holes with Skyrme hair, including the discovery of spherically symmetric black hole skyrmions with B=1 and axially symmetric B=2 black hole skyrmions. It discusses how black holes can absorb baryon number, leading to fractional charge outside the horizon. The paper also extends the model to gauged versions for monopole black hole skyrmions and explores multi-black hole skyrmion solutions where gravitational, electromagnetic, and strong forces are balanced, proving their stability under perturbations.
#     *   **Source:** arXiv (http://arxiv.org/abs/gr-qc/0501025v1)
#
# 2.  **Title:** Galaxy bulges and their massive black holes: a review
#     *   **Authors:** Alister W. Graham
#     *   **Published:** 2015-01-13
#     *   **Summary:** This article reviews the historical development of our understanding of massive black holes at galactic centers, including the evolution of the (black hole)-(host spheroid) mass relation and its recent revisions. It also addresses past disagreements about the slope of the (black hole)-(velocity dispersion) relation and discusses the discovery of substructure within this diagram. The paper presents various competing black hole mass scaling relations for samples of predominantly inactive galaxies as the search for the fundamental connection between massive black holes and their host galaxies continues.
#     *   **Source:** arXiv (http://arxiv.org/abs/1501.02937v3)</code></pre></div>

# %%
# list of preferred domains for Tavily results
TOP_DOMAINS = {
    # General reference / institutions / publishers
    "wikipedia.org", "nature.com", "science.org", "sciencemag.org", "cell.com",
    "mit.edu", "stanford.edu", "harvard.edu", "nasa.gov", "noaa.gov", "europa.eu",

    # CS/AI venues & indexes
    "arxiv.org", "acm.org", "ieee.org", "neurips.cc", "icml.cc", "openreview.net",

    # Other reputable outlets
    "elifesciences.org", "pnas.org", "jmlr.org", "springer.com", "sciencedirect.com",

    # Extra domains (case-specific additions)
    "pbs.org", "nova.edu", "nvcc.edu", "cccco.edu",

    # Well known programming sites
    "codecademy.com", "datacamp.com"
}

def evaluate_tavily_results(TOP_DOMAINS, raw: str, min_ratio=0.4):
    """
    Evaluate whether plain-text research results mostly come from preferred domains.

    Args:
        TOP_DOMAINS (set[str]): Set of preferred domains (e.g., 'arxiv.org', 'nature.com').
        raw (str): Plain text or Markdown containing URLs.
        min_ratio (float): Minimum preferred ratio required to pass (e.g., 0.4 = 40%).

    Returns:
        tuple[bool, str]: (flag, markdown_report)
            flag -> True if PASS, False if FAIL
            markdown_report -> Markdown-formatted summary of the evaluation
    """

    # Extract URLs from the text
    url_pattern = re.compile(r'https?://[^\s\]\)>\}]+', flags=re.IGNORECASE)
    urls = url_pattern.findall(raw)

    if not urls:
        return False, """### Evaluation — Tavily Preferred Domains
No URLs detected in the provided text. 
Please include links in your research results.
"""

    # Count preferred vs total
    total = len(urls)
    preferred_count = 0
    details = []

    for url in urls:
        domain = url.split("/")[2]
        preferred = any(td in domain for td in TOP_DOMAINS)
        if preferred:
            preferred_count += 1
        details.append(f"- {url} → {'✅ PREFERRED' if preferred else '❌ NOT PREFERRED'}")

    ratio = preferred_count / total if total > 0 else 0.0
    flag = ratio >= min_ratio

    # Markdown report
    report = f"""
### Evaluation — Tavily Preferred Domains
- Total results: {total}
- Preferred results: {preferred_count}
- Ratio: {ratio:.2%}
- Threshold: {min_ratio:.0%}
- Status: {"✅ PASS" if flag else "❌ FAIL"}

**Details:**
{chr(10).join(details)}
"""
    return flag, report

# %%
utils.print_html(json.dumps(list(TOP_DOMAINS)[:4], indent=2), title="Sample Trusted Domains")

utils.print_html("<h3>Research Results</h3>" + research_result, title="Research Results")

flag, report = evaluate_tavily_results(TOP_DOMAINS, research_result)
utils.print_html("<pre>" + report + "</pre>", title="<h3>Evaluation Summary</h3>")
# Out:
#     <style>
#     .pretty-card{
#       font-family: ui-sans-serif, system-ui;
#       border: 2px solid transparent;
#       border-radius: 14px;
#       padding: 14px 16px;
#       margin: 10px 0;
#       background: linear-gradient(#fff, #fff) padding-box,
#                   linear-gradient(135deg, #3b82f6, #9333ea) border-box;
#       color: #111;
#       box-shadow: 0 4px 12px rgba(0,0,0,.08);
#     }
#     .pretty-title{
#       font-weight:700;
#       margin-bottom:8px;
#       font-size:14px;
#       color:#111;
#     }
#     /* 🔒 Solo afecta lo DENTRO de la tarjeta */
#     .pretty-card pre,
#     .pretty-card code {
#       background: #f3f4f6;
#       color: #111;
#       padding: 8px;
#       border-radius: 8px;
#       display: block;
#       overflow-x: auto;
#       font-size: 13px;
#       white-space: pre-wrap;
#     }
#     .pretty-card img { max-width: 100%; height: auto; border-radius: 8px; }
#     .pretty-card table.pretty-table {
#       border-collapse: collapse;
#       width: 100%;
#       font-size: 13px;
#       color: #111;
#     }
#     .pretty-card table.pretty-table th,
#     .pretty-card table.pretty-table td {
#       border: 1px solid #e5e7eb;
#       padding: 6px 8px;
#       text-align: left;
#     }
#     .pretty-card table.pretty-table th { background: #f9fafb; font-weight: 600; }
#     </style>
#     <div class="pretty-card"><div class="pretty-title">Sample Trusted Domains</div><pre><code>[
#   &quot;ieee.org&quot;,
#   &quot;harvard.edu&quot;,
#   &quot;springer.com&quot;,
#   &quot;noaa.gov&quot;
# ]</code></pre></div>
#     <style>
#     .pretty-card{
#       font-family: ui-sans-serif, system-ui;
#       border: 2px solid transparent;
#       border-radius: 14px;
#       padding: 14px 16px;
#       margin: 10px 0;
#       background: linear-gradient(#fff, #fff) padding-box,
#                   linear-gradient(135deg, #3b82f6, #9333ea) border-box;
#       color: #111;
#       box-shadow: 0 4px 12px rgba(0,0,0,.08);
#     }
#     .pretty-title{
#       font-weight:700;
#       margin-bottom:8px;
#       font-size:14px;
#       color:#111;
#     }
#     /* 🔒 Solo afecta lo DENTRO de la tarjeta */
#     .pretty-card pre,
#     .pretty-card code {
#       background: #f3f4f6;
#       color: #111;
#       padding: 8px;
#       border-radius: 8px;
#       display: block;
#       overflow-x: auto;
#       font-size: 13px;
#       white-space: pre-wrap;
#     }
#     .pretty-card img { max-width: 100%; height: auto; border-radius: 8px; }
#     .pretty-card table.pretty-table {
#       border-collapse: collapse;
#       width: 100%;
#       font-size: 13px;
#       color: #111;
#     }
#     .pretty-card table.pretty-table th,
#     .pretty-card table.pretty-table td {
#       border: 1px solid #e5e7eb;
#       padding: 6px 8px;
#       text-align: left;
#     }
#     .pretty-card table.pretty-table th { background: #f9fafb; font-weight: 600; }
#     </style>
#     <div class="pretty-card"><div class="pretty-title">Research Results</div><pre><code>&lt;h3&gt;Research Results&lt;/h3&gt;Here are two papers on black hole science:
#
# 1.  **Black Holes with Skyrme Hair** by Noriko Shiiki and Nobuyuki Sawado.
#     *   **Summary:** This paper reviews recent developments on black holes with Skyrme hair. It discusses the discovery of spherically symmetric and axially symmetric black hole skyrmions, which challenge the no-hair conjecture. The paper also explores the extension to gauged versions, describing monopole black hole skyrmions and multi-black hole skyrmion solutions, where gravitational, electromagnetic, and strong forces are balanced.
#     *   **Published:** 2005-01-09
#     *   **Source:** [arXiv](http://arxiv.org/abs/gr-qc/0501025v1)
#
# 2.  **Galaxy bulges and their massive black holes: a review** by Alister W. Graham.
#     *   **Summary:** This article reviews the evolution of our understanding of massive black holes at galactic centers. It traces the historical development of the near-linear (black hole)-(host spheroid) mass relation and explains its recent revisions. The paper also addresses past disagreements on the slope of the (black hole)-(velocity dispersion) relation and discusses the discovery of substructure within the diagram. It concludes by presenting various black hole mass scaling relations for inactive galaxies.
#     *   **Published:** 2015-01-13
#     *   **Source:** [arXiv](http://arxiv.org/abs/1501.02937v3)</code></pre></div>
#     <style>
#     .pretty-card{
#       font-family: ui-sans-serif, system-ui;
#       border: 2px solid transparent;
#       border-radius: 14px;
#       padding: 14px 16px;
#       margin: 10px 0;
#       background: linear-gradient(#fff, #fff) padding-box,
#                   linear-gradient(135deg, #3b82f6, #9333ea) border-box;
#       color: #111;
#       box-shadow: 0 4px 12px rgba(0,0,0,.08);
#     }
#     .pretty-title{
#       font-weight:700;
#       margin-bottom:8px;
#       font-size:14px;
#       color:#111;
#     }
#     /* 🔒 Solo afecta lo DENTRO de la tarjeta */
#     .pretty-card pre,
#     .pretty-card code {
#       background: #f3f4f6;
#       color: #111;
#       padding: 8px;
#       border-radius: 8px;
#       display: block;
#       overflow-x: auto;
#       font-size: 13px;
#       white-space: pre-wrap;
#     }
#     .pretty-card img { max-width: 100%; height: auto; border-radius: 8px; }
#     .pretty-card table.pretty-table {
#       border-collapse: collapse;
#       width: 100%;
#       font-size: 13px;
#       color: #111;
#     }
#     .pretty-card table.pretty-table th,
#     .pretty-card table.pretty-table td {
#       border: 1px solid #e5e7eb;
#       padding: 6px 8px;
#       text-align: left;
#     }
#     .pretty-card table.pretty-table th { background: #f9fafb; font-weight: 600; }
#     </style>
#     <div class="pretty-card"><div class="pretty-title"><h3>Evaluation Summary</h3></div><pre><code>&lt;pre&gt;
# ### Evaluation — Tavily Preferred Domains
# - Total results: 2
# - Preferred results: 2
# - Ratio: 100.00%
# - Threshold: 40%
# - Status: ✅ PASS
#
# **Details:**
# - http://arxiv.org/abs/gr-qc/0501025v1 → ✅ PREFERRED
# - http://arxiv.org/abs/1501.02937v3 → ✅ PREFERRED
# &lt;/pre&gt;</code></pre></div>
